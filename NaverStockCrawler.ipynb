# %%
import re
import requests
import urlparse
import datetime
import json
from time import sleep
import random
from bs4 import BeautifulSoup

# %%
def find_between( s, first, last ):
    try:
        start = s.index( first ) + len( first )
        end = s.index( last, start )
        return s[ start : end ]
    except ValueError:
        return ""
    
def find_between_r( s, first, last ):
    try:
        start = s.rindex( first ) + len( first )
        end = s.rindex( last, start )
        return s[ start : end ]
    except ValueError:
        return ""
    
def find_between_h( s, first, last ):
    try:
        start = s.index( first ) + len( first )
        end = s.rindex( last, start )
        return s[ start : end ]
    except ValueError:
        return ""

def find_item( s, name, first, last, find_func = find_between ):
    start = s.index( name ) + len( name )
    return find_func( s[ start : ], first, last )

# %%
class NaverStockCrawler( object ):
    def __init__( self, code ):
        self.nvr_fnc_url = "http://finance.naver.com"
        self.code = code
        self.cur_page = 1
        self.stock_bbs_url = "http://finance.naver.com/item/board.nhn?code={}&page={}" 
        self.cur_board_url = self.stock_bbs_url.format( self.code, self.cur_page )
               
    def set_date( self, begin, end ): pass
    
    def set_page( self, page ):
        assert page > 0
        self.cur_page = page
        self.cur_board_url = self.stock_bbs_url.format( self.code, self.cur_page )
        return self.cur_board_url

    def crawl_web( self, url = '' ):
        if len( url ) < 1:
            url = self.cur_board_url
            
        res = requests.get( url )
        soup = BeautifulSoup( res.content )
        return soup
    
    def extract_top_bbs( self, soup ):
        # information extraction: 
        # sympathy, antipathy, written_date, title, investment_opinion, hits, id
        
        table = []
        col_title = ["written_date", "title", "inv_op", "id", "hits", "sympathy", "antipathy"]
        rows = soup.find_all( 'tr', attrs = {"onmouseover":"mouseOver(this)", \
                                             "onmouseout" : "mouseOut(this)"} )
        # Seperate rows and columns
        for r in rows:
            col_items = r.find_all( 'td' )
            tmp_dict = {}
            for idx, item in  enumerate( col_items ):
                if col_title[ idx ] is "title": 
                    href = item.select_one( 'a["href^=/item/board_read.nhn"]' )
                    css_str = str( href )
                    
                    article_url = find_item( css_str, "href=", '"', '"' )
                    article_url = article_url.replace( "amp;", "" )
                    tmp_dict[ "article_sub_url" ] = article_url
                    
                    #tmp_dict[ col_title[ idx ] ] = find_item( item.text, '', '\n', '\n' )
                    title = find_item( css_str, "title=", '"', '"' )
                    tmp_dict[ col_title[ idx ] ] = " ".join( title.strip().split() )
                    
                    is_sub = item.find( 'img', attrs = { 'alt':u'답글'} )
                    tmp_dict[ "is_sub" ] = True if is_sub is not None else False
               
                else:
                    tmp_dict[ col_title[idx] ] = item.text
            
            #tmp_dict["id"] = find_item( tmp_dict["id"], '', '\n\t\t\t\t', '\n\t\t\t\t' )
            tmp_dict[ "id" ] = tmp_dict[ "id" ].strip()
            table.append( tmp_dict )
            
        return table
    
    def extract_article( self, soup ):
        body = soup.find( "div", class_ = "view_se", id = "body" )     
        article = "\n".join( [ " ".join( line.strip().split() ) for line in body.text.splitlines() ] )
        return article
    
    def extract_cmt_url( self, soup ):
        cmt_soup = soup.find( "iframe", id = 'ncomment' )
        element = find_item( str( cmt_soup ), "src", '"', '"' ).replace( "amp;", "" )
        cmt_url = self.nvr_fnc_url + element
        return cmt_url

    def crawl_cmt( self, cmt_iframe_url, page_no = 1, page_size = 50 ):
        assert page_no > 0 and page_size > 0
        query_dict = urlparse.parse_qs( urlparse.urlsplit( cmt_iframe_url ).query )
        
        post_url = "http://finance.naver.com/comments/list_comment.nhn"
        headers = {}
        #headers['_ts']='1481278972259'
        headers['ticket'] = query_dict[ "ticketId" ][0]
        headers['object_id'] = query_dict[ "objectId" ][0]
        headers['lkey'] = query_dict[ "secureKey" ][0]
        headers['page_size'] = str( page_size )
        headers['page_no'] = str( page_no )
        
        res_cmt = requests.post( post_url, data = headers )
        return json.loads( res_cmt.content )
    
    def crawl_cmt_loop( self, cmt_iframe_url, page_size = 50 ):
        assert page_size > 0
        cmt_table = []
        cmt_col_title = [ "registered_ymdt", "contents", "writer_id", "object_id", "comment_no" ]
        accumulated_page_size = 0
        total_cmt_cnt = page_size
        page_no = 1
        
        while accumulated_page_size < total_cmt_cnt:
            cmt_json = self.crawl_cmt( cmt_iframe_url, page_no = page_no, page_size = page_size )
        
            if cmt_json["error"]["message"] != "No Error" : return cmt_table
           
            total_cmt_cnt = cmt_json[ "total_count" ]
       
            for i in cmt_json[ "comment_list" ]:
                cmt_row = {}
                for key, item in i.items():
                    if key in cmt_col_title:
                        cmt_row[ key ] = item
                cmt_table.append( cmt_row )

            page_no += 1
            accumulated_page_size += page_size
            
        return cmt_table
        
    def start_crawler( self ):
        soup = self.crawl_web()
        table = self.extract_top_bbs( soup )
        for t in table:
            for k, i in t.items():
                if k == "article_sub_url" : 
                    print k, ": ", self.nvr_fnc_url + i
                    delay = random.randint( 0, 100 )
                    sleep( delay * 0.01 )
                    
                    sub_soup = self.crawl_web( self.nvr_fnc_url + i )

                    article = self.extract_article( sub_soup )
                    cmt_url = self.extract_cmt_url( sub_soup )

                    print "article: ", article
                    print "cmt_url: ", cmt_url
                    
                    cmts = self.crawl_cmt_loop( cmt_url, 2 )
                    print
                    for cmt in cmts:
                        for ck, ci in cmt.items():
                            print ck, ": ", ci
                        print
                else:
                    print k,": ", i
            print "=" * 90

# %%
stock_crawler = NaverStockCrawler( "037230" ) # 한국패키지
stock_crawler.set_page( 1 )
stock_crawler.start_crawler()
test_cmt_url = "http://finance.naver.com/ncomment/list.nhn?ticketId=finance2&objectId=56425873&secureKey=j-2rP7uK5gJKNggDWeTmm5s8zoq5b4vHtF-2LA6d7h6HgMDPp4Wzsw&parentUrl=http%3A%2F%2Ffinance.naver.com%2Fitem%2Fboard_read.nhn%3Fcode%3D037230%26nid%3D56425873%26st%3D%26sw%3D%26page%3D3"
#stock_crawler.crawl_cmt( test_cmt_url, 1, 0 )
#stock_crawler.crawl_cmt_loop( test_cmt_url, 1 )
# Out:
# article_sub_url :  http://finance.naver.com/item/board_read.nhn?code=037230&nid=56502652&st=&sw=&page=1
# article:  지지률상승
# 이재명 화이팅
# cmt_url:  http://finance.naver.com/ncomment/list.nhn?ticketId=finance2&objectId=56502652&secureKey=j-2rP7uK5gKjvSiNtnYfWDWT_CBzRfR-geGWe0tiLFVNKC4TeZgvFQ&parentUrl=http%3A%2F%2Ffinance.naver.com%2Fitem%2Fboard_read.nhn%3Fcode%3D037230%26nid%3D56502652%26st%3D%26sw%3D%26page%3D1
#
# hits :  114
# title :  주말 촛불집회
# written_date :  2016.12.16 18:03
# is_sub :  False
# antipathy :  2
# sympathy :  2
# id :  pjh5****
# inv_op :  의견없음
# ==========================================================================================
# article_sub_url :  http://finance.naver.com/item/board_read.nhn?code=037230&nid=56500458&st=&sw=&page=1
# article:  조례지정!
# 경기도지사 멋지네용.
# 벌써 움직이네요.
# 액션이 빠르네용.
# cmt_url:  http://finance.naver.com/ncomment/list.nhn?ticketId=finance2&objectId=56500458&secureKey=j-2rP7uK5gKxWt5yY9NIE5MbF_wd6lZSgeGWe0tiLFWk9cOo678kzg&parentUrl=http%3A%2F%2Ffinance.naver.com%2Fitem%2Fboard_read.nhn%3Fcode%3D037230%26nid%3D56500458%26st%3D%26sw%3D%26page%3D1
#
# hits :  100
# title :  경기도 무상급식지원
# written_date :  2016.12.16 17:03
# is_sub :  False
# antipathy :  0
# sympathy :  5
# id :  msoh****
# inv_op :  의견없음
# ==========================================================================================
# article_sub_url :  http://finance.naver.com/item/board_read.nhn?code=037230&nid=56497404&st=&sw=&page=1
# article:  한팩 흐름이 양호허다
# cmt_url:  http://finance.naver.com/ncomment/list.nhn?ticketId=finance2&objectId=56497404&secureKey=j-2rP7uK5gIJdtdTmDB_THQyQqqY72XKgeGWe0tiLFUbHfRcFNvWww&parentUrl=http%3A%2F%2Ffinance.naver.com%2Fitem%2Fboard_read.nhn%3Fcode%3D037230%26nid%3D56497404%26st%3D%26sw%3D%26page%3D1
#
# hits :  149
# title :  요즘
# written_date :  2016.12.16 15:54
# is_sub :  False
# antipathy :  0
# sympathy :  2
# id :  lch5****
# inv_op :  의견없음
# ==========================================================================================
# article_sub_url :  http://finance.naver.com/item/board_read.nhn?code=037230&nid=56491150&st=&sw=&page=1
# article:  세력들 장중조정 잘하고 있네요 세력들에게 물량 뺏기지 마시고 잘들 끝까지 홀딩해서 다같이 대박납시다
# cmt_url:  http://finance.naver.com/ncomment/list.nhn?ticketId=finance2&objectId=56491150&secureKey=j-2rP7uK5gIarlnosTT4eTuXWp8IqYJegeGWe0tiLFUdAaFk-V_2_g&parentUrl=http%3A%2F%2Ffinance.naver.com%2Fitem%2Fboard_read.nhn%3Fcode%3D037230%26nid%3D56491150%26st%3D%26sw%3D%26page%3D1
#
# comment_no :  67698315
# writer_id :  qkrt****
# object_id :  56491150
# registered_ymdt :  2016-12-16T22:02:17.0+0900
# contents :  밑에 카페글, 저게 사실이면ㄷㄷ
#
# comment_no :  67682703
# writer_id :  seos****
# object_id :  56491150
# registered_ymdt :  2016-12-16T15:52:45.0+0900
# contents :  개
#
# hits :  150
# title :  조정 잘받네요 끝까지 홀딩절약 세력들에게 물량 뺏기지.
# written_date :  2016.12.16 14:53
# is_sub :  False
# antipathy :  1
# sympathy :  1
# id :  qorr****
# inv_op :  의견없음
# ==========================================================================================
# article_sub_url :  http://finance.naver.com/item/board_read.nhn?code=037230&nid=56481690&st=&sw=&page=1
# article:  그라고 니 가천대 어디 있는 줄아냐?
# 난 가천대 알지롱 롱 롱 멍청한 시장님아~
# 넌 앞으로 조금 더 입 나불거리면 성남시민들이 널 탄핵할끼다
# 입만 나불거리는 생쥐같은 기
# cmt_url:  http://finance.naver.com/ncomment/list.nhn?ticketId=finance2&objectId=56481690&secureKey=j-2rP7uK5gJcZbKcF87I3juXWp8IqYJegeGWe0tiLFUl5k30HjudYg&parentUrl=http%3A%2F%2Ffinance.naver.com%2Fitem%2Fboard_read.nhn%3Fcode%3D037230%26nid%3D56481690%26st%3D%26sw%3D%26page%3D1
#
# comment_no :  67696718
# writer_id :  omrc****
# object_id :  56481690
# registered_ymdt :  2016-12-16T20:52:28.0+0900
# contents :  맞는 말했군요.
# 형수의 은밀한 부위를 놓고 욕을 하는 못된 녀석이 무슨 정치를, 무슨 대통령을 한다고 설치는지~~^^
#
# comment_no :  67694934
# writer_id :  lkb6****
# object_id :  56481690
# registered_ymdt :  2016-12-16T19:41:12.0+0900
# contents :  성남을 떠나라
# 좋은걸 가지고 있을땐 몰라
# 잃어봐야  소중한걸 알지
#
# comment_no :  67676949
# writer_id :  seos****
# object_id :  56481690
# registered_ymdt :  2016-12-16T14:50:10.0+0900
# contents :  살지마라
#
# comment_no :  67670758
# writer_id :  myyo****
# object_id :  56481690
# registered_ymdt :  2016-12-16T13:26:55.0+0900
# contents :  이재명 차기 대통령님
# 존중해야지요?
# 욕설은 자제해주시고
# 비판은 정확히
#
# hits :  152
# title :  아직도 형수한테 욕하고 댕기나
# written_date :  2016.12.16 13:09
# is_sub :  False
# antipathy :  5
# sympathy :  2
# id :  salg****
# inv_op :  의견없음
# ==========================================================================================
# article_sub_url :  http://finance.naver.com/item/board_read.nhn?code=037230&nid=56476996&st=&sw=&page=1
# article:  역시 입만 나불거린다고 국민들이 속지는 않지
# 국민들이 바보인줄아냐?
# 입만 나불거리다 끝난 이재명 퉤퉤~ 에이 쓰어버럴
# cmt_url:  http://finance.naver.com/ncomment/list.nhn?ticketId=finance2&objectId=56476996&secureKey=j-2rP7uK5gKum0I9XG9hWnSOXBriLItsgeGWe0tiLFVIwIEx1SSHIQ&parentUrl=http%3A%2F%2Ffinance.naver.com%2Fitem%2Fboard_read.nhn%3Fcode%3D037230%26nid%3D56476996%26st%3D%26sw%3D%26page%3D1
#
# comment_no :  67667477
# writer_id :  pjh5****
# object_id :  56476996
# registered_ymdt :  2016-12-16T12:40:40.0+0900
# contents :  ㅁ 선전하지 마셔  ㅎ ㅎ
# 이재멍이도어야 나라가 바로서는걸
# 왜 몰시나   윈
#
# comment_no :  67667129
# writer_id :  seos****
# object_id :  56476996
# registered_ymdt :  2016-12-16T12:36:03.0+0900
# contents :  ㄷ ㅅ
#
# hits :  185
# title :  이재명이 결국 입만 나불거리다 끝났네
# written_date :  2016.12.16 12:02
# is_sub :  False
# antipathy :  4
# sympathy :  3
# id :  salg****
# inv_op :  의견없음
# ==========================================================================================
# article_sub_url :  http://finance.naver.com/item/board_read.nhn?code=037230&nid=56474579&st=&sw=&page=1
# article:  오늘 팔고
# 다른곳으로 가셔
# 눈에 보이는 주식을
# 팔다니 원
# 주식 첨하나
# 지금 한팩만한 주식
# 찾기 쉽지 안오 ㅎ
# 8천이상은 가야지
# 반톄마 대부분 8천이상
# 안보이나봐
# cmt_url:  http://finance.naver.com/ncomment/list.nhn?ticketId=finance2&objectId=56474579&secureKey=j-2rP7uK5gLrDvxAJc--cb_puGNuuBeigeGWe0tiLFVFLFt_brDniA&parentUrl=http%3A%2F%2Ffinance.naver.com%2Fitem%2Fboard_read.nhn%3Fcode%3D037230%26nid%3D56474579%26st%3D%26sw%3D%26page%3D1
#
# hits :  142
# title :  새가슴 개미들은
# written_date :  2016.12.16 11:32
# is_sub :  False
# antipathy :  0
# sympathy :  2
# id :  pjh5****
# inv_op :  의견없음
# ==========================================================================================
# article_sub_url :  http://finance.naver.com/item/board_read.nhn?code=037230&nid=56470407&st=&sw=&page=1
# article:  이거ㅇㅈ?
# cmt_url:  http://finance.naver.com/ncomment/list.nhn?ticketId=finance2&objectId=56470407&secureKey=j-2rP7uK5gKj4xm3_W-cMVyaIpV11pokgeGWe0tiLFUfrEBQ8kPA9g&parentUrl=http%3A%2F%2Ffinance.naver.com%2Fitem%2Fboard_read.nhn%3Fcode%3D037230%26nid%3D56470407%26st%3D%26sw%3D%26page%3D1
#
# hits :  167
# title :  관상을 보아하니..4만원은 가겟구나
# written_date :  2016.12.16 10:43
# is_sub :  False
# antipathy :  1
# sympathy :  1
# id :  like****
# inv_op :  의견없음
# ==========================================================================================
# article_sub_url :  http://finance.naver.com/item/board_read.nhn?code=037230&nid=56468007&st=&sw=&page=1
# article:  이번 대선은 이재명이 후보가 안되더라도 무상급식이 이슈가 될듯~
# 가만히 담아두면 한번은 시세 줄듯~ 모두 즐투 하세요
# cmt_url:  http://finance.naver.com/ncomment/list.nhn?ticketId=finance2&objectId=56468007&secureKey=j-2rP7uK5gKN4htGmaYzv1yaIpV11pokgeGWe0tiLFVof9m-yvIeSg&parentUrl=http%3A%2F%2Ffinance.naver.com%2Fitem%2Fboard_read.nhn%3Fcode%3D037230%26nid%3D56468007%26st%3D%26sw%3D%26page%3D1
#
# hits :  141
# title :  무상급식~?
# written_date :  2016.12.16 10:17
# is_sub :  False
# antipathy :  1
# sympathy :  7
# id :  jhle****
# inv_op :  의견없음
# ==========================================================================================
# article_sub_url :  http://finance.naver.com/item/board_read.nhn?code=037230&nid=56466980&st=&sw=&page=1
# article:  어때요 차트는 속일수 없다는걸 끝까지 홀딩입니다 세력들 고생한다 고맙습니다 더 힘내주시길
# cmt_url:  http://finance.naver.com/ncomment/list.nhn?ticketId=finance2&objectId=56466980&secureKey=j-2rP7uK5gKKbz0-CPFqVTuXWp8IqYJegeGWe0tiLFUrpCem-5MtFQ&parentUrl=http%3A%2F%2Ffinance.naver.com%2Fitem%2Fboard_read.nhn%3Fcode%3D037230%26nid%3D56466980%26st%3D%26sw%3D%26page%3D1
#
# comment_no :  67657108
# writer_id :  qkrn****
# object_id :  56466980
# registered_ymdt :  2016-12-16T10:27:43.0+0900
# contents :  junw****님 좋은글 잘읽을께요~
#
# comment_no :  67656918
# writer_id :  junw****
# object_id :  56466980
# registered_ymdt :  2016-12-16T10:25:36.0+0900
# contents :  한국팩키지 역시나 종목 , 읽어보시면 도움될꺼예요
# blog.naver.com/wwpaj67/220886547310
#
# hits :  170
# title :  좋습니다 수익..2차 상승..
# written_date :  2016.12.16 10:06
# is_sub :  False
# antipathy :  1
# sympathy :  2
# id :  qorr****
# inv_op :  의견없음
# ==========================================================================================
# article_sub_url :  http://finance.naver.com/item/board_read.nhn?code=037230&nid=56466777&st=&sw=&page=1
# article:  다음주 5천원 돌파할라
# cmt_url:  http://finance.naver.com/ncomment/list.nhn?ticketId=finance2&objectId=56466777&secureKey=j-2rP7uK5gKWB78N1hnj-VyaIpV11pokgeGWe0tiLFUw-1iZH67Zcg&parentUrl=http%3A%2F%2Ffinance.naver.com%2Fitem%2Fboard_read.nhn%3Fcode%3D037230%26nid%3D56466777%26st%3D%26sw%3D%26page%3D1
#
# comment_no :  67656106
# writer_id :  wsha****
# object_id :  56466777
# registered_ymdt :  2016-12-16T10:15:07.0+0900
# contents :  제에발...
#
# hits :  127
# title :  오늘 10프로 올리고
# written_date :  2016.12.16 10:04
# is_sub :  False
# antipathy :  0
# sympathy :  1
# id :  supe****
# inv_op :  의견없음
# ==========================================================================================
# article_sub_url :  http://finance.naver.com/item/board_read.nhn?code=037230&nid=56465709&st=&sw=&page=1
# article:  꾹꾹 누르고 있음
# 누를수록 폭발력만 커질뿐..
# cmt_url:  http://finance.naver.com/ncomment/list.nhn?ticketId=finance2&objectId=56465709&secureKey=j-2rP7uK5gKaEA6l6fFrJ7_puGNuuBeigeGWe0tiLFWHD8VaXqajAQ&parentUrl=http%3A%2F%2Ffinance.naver.com%2Fitem%2Fboard_read.nhn%3Fcode%3D037230%26nid%3D56465709%26st%3D%26sw%3D%26page%3D1
#
# hits :  109
# title :  상승본능..
# written_date :  2016.12.16 09:55
# is_sub :  False
# antipathy :  0
# sympathy :  3
# id :  rok5****
# inv_op :  의견없음
# ==========================================================================================
# article_sub_url :  http://finance.naver.com/item/board_read.nhn?code=037230&nid=56463390&st=&sw=&page=1
# article:  3류 세력한테 뭘~^^
# 지엔코 세력 반만따라 하세요
# cmt_url:  http://finance.naver.com/ncomment/list.nhn?ticketId=finance2&objectId=56463390&secureKey=j-2rP7uK5gISCV7c0beC4juXWp8IqYJegeGWe0tiLFWupQskBXv2-Q&parentUrl=http%3A%2F%2Ffinance.naver.com%2Fitem%2Fboard_read.nhn%3Fcode%3D037230%26nid%3D56463390%26st%3D%26sw%3D%26page%3D1
#
# hits :  110
# title :  3류 세력한테
# written_date :  2016.12.16 09:34
# is_sub :  False
# antipathy :  0
# sympathy :  2
# id :  pjh5****
# inv_op :  의견없음
# ==========================================================================================
# article_sub_url :  http://finance.naver.com/item/board_read.nhn?code=037230&nid=56463211&st=&sw=&page=1
# article:  비나이딘
# cmt_url:  http://finance.naver.com/ncomment/list.nhn?ticketId=finance2&objectId=56463211&secureKey=j-2rP7uK5gLqE5eXepQaWmmrbyp795rXgeGWe0tiLFUV3YqeHO-hJQ&parentUrl=http%3A%2F%2Ffinance.naver.com%2Fitem%2Fboard_read.nhn%3Fcode%3D037230%26nid%3D56463211%26st%3D%26sw%3D%26page%3D1
#
# comment_no :  67653333
# writer_id :  lch5****
# object_id :  56463211
# registered_ymdt :  2016-12-16T09:40:15.0+0900
# contents :  ㄹㄹ 그러케 마니 ㅎㅎ
#
# hits :  97
# title :  주포형님 5천원가주세요
# written_date :  2016.12.16 09:33
# is_sub :  False
# antipathy :  1
# sympathy :  2
# id :  sobb****
# inv_op :  의견없음
# ==========================================================================================
# article_sub_url :  http://finance.naver.com/item/board_read.nhn?code=037230&nid=56462887&st=&sw=&page=1
# article:  보인다.
# 쭉쭉가보자
# cmt_url:  http://finance.naver.com/ncomment/list.nhn?ticketId=finance2&objectId=56462887&secureKey=j-2rP7uK5gJ0bE2Tag41eFyaIpV11pokgeGWe0tiLFWbJixnhd13gA&parentUrl=http%3A%2F%2Ffinance.naver.com%2Fitem%2Fboard_read.nhn%3Fcode%3D037230%26nid%3D56462887%26st%3D%26sw%3D%26page%3D1
#
# comment_no :  67653205
# writer_id :  lch5****
# object_id :  56462887
# registered_ymdt :  2016-12-16T09:38:35.0+0900
# contents :  ㅎㅎㅎ
#
# hits :  101
# title :  날라가고 싶어 미치겠는듯
# written_date :  2016.12.16 09:29
# is_sub :  False
# antipathy :  0
# sympathy :  3
# id :  supe****
# inv_op :  의견없음
# ==========================================================================================
# article_sub_url :  http://finance.naver.com/item/board_read.nhn?code=037230&nid=56462480&st=&sw=&page=1
# article:  오늘 조정끝 상승시작 세력들 차트 다만들어놓고 뜸들이네요 다보이는데 끝까지 홀딩할려는 이유가 여기 있지요 다보여요 다들 끝까지 홀딩해보세요 세력들이 대박을내주나 안내주나 보게요 다보입니다 대박이..오늘부터 억억 소리..
# cmt_url:  http://finance.naver.com/ncomment/list.nhn?ticketId=finance2&objectId=56462480&secureKey=j-2rP7uK5gKBzIiQlBHhuzuXWp8IqYJegeGWe0tiLFU3V2CZ32pjmg&parentUrl=http%3A%2F%2Ffinance.naver.com%2Fitem%2Fboard_read.nhn%3Fcode%3D037230%26nid%3D56462480%26st%3D%26sw%3D%26page%3D1
#
# hits :  98
# title :  조정끝 상승시작 차트 다만들어놓고 세력들..
# written_date :  2016.12.16 09:25
# is_sub :  False
# antipathy :  0
# sympathy :  1
# id :  qorr****
# inv_op :  의견없음
# ==========================================================================================
# article_sub_url :  http://finance.naver.com/item/board_read.nhn?code=037230&nid=56462413&st=&sw=&page=1
# article:  매수
# 5천원은 가볍게 넘겠지??
# cmt_url:  http://finance.naver.com/ncomment/list.nhn?ticketId=finance2&objectId=56462413&secureKey=j-2rP7uK5gJ6Zkj0xEretJs8zoq5b4vHgeGWe0tiLFW83UHWPlpBuQ&parentUrl=http%3A%2F%2Ffinance.naver.com%2Fitem%2Fboard_read.nhn%3Fcode%3D037230%26nid%3D56462413%26st%3D%26sw%3D%26page%3D1
#
# hits :  156
# title :  초강력매수
# written_date :  2016.12.16 09:25
# is_sub :  False
# antipathy :  0
# sympathy :  1
# id :  supe****
# inv_op :  의견없음
# ==========================================================================================
# article_sub_url :  http://finance.naver.com/item/board_read.nhn?code=037230&nid=56461824&st=&sw=&page=1
# article:  오늘의 저점은 찍었다는 사실..
# 그럼 남은 시간은 뭐다?
# 주구장창 오를일만 남았다
# cmt_url:  http://finance.naver.com/ncomment/list.nhn?ticketId=finance2&objectId=56461824&secureKey=j-2rP7uK5gJd2_2QqZ8s93QyQqqY72XKgeGWe0tiLFWE7zY0LkFxDw&parentUrl=http%3A%2F%2Ffinance.naver.com%2Fitem%2Fboard_read.nhn%3Fcode%3D037230%26nid%3D56461824%26st%3D%26sw%3D%26page%3D1
#
# hits :  106
# title :  확실한 팩트 한가지
# written_date :  2016.12.16 09:18
# is_sub :  False
# antipathy :  0
# sympathy :  2
# id :  rok5****
# inv_op :  의견없음
# ==========================================================================================
# article_sub_url :  http://finance.naver.com/item/board_read.nhn?code=037230&nid=56459394&st=&sw=&page=1
# article:  오늘부터 완전 상승으로 지지난주 금요일 미수 몰빵한거 드뎌 제대로된 수익 내겠군요 하루에 억억 소리들을것 같군요 다같이 끝까지 홀딩해서 다같이 대박납시다 세력들 위에서 편한히 매도하고 나옵시다 오늘은
# cmt_url:  http://finance.naver.com/ncomment/list.nhn?ticketId=finance2&objectId=56459394&secureKey=j-2rP7uK5gLI2_Vr8wYPGHQyQqqY72XKgeGWe0tiLFX6gSb94x7nMQ&parentUrl=http%3A%2F%2Ffinance.naver.com%2Fitem%2Fboard_read.nhn%3Fcode%3D037230%26nid%3D56459394%26st%3D%26sw%3D%26page%3D1
#
# hits :  114
# title :  오늘부터 대박입니다 가자 다같이 대박..
# written_date :  2016.12.16 08:27
# is_sub :  False
# antipathy :  0
# sympathy :  2
# id :  qorr****
# inv_op :  의견없음
# ==========================================================================================
# article_sub_url :  http://finance.naver.com/item/board_read.nhn?code=037230&nid=56459580&st=&sw=&page=1
# article:  오늘은 사천 오백원 넘어가겠군요 오늘부터 억억 소리한번 다같이 내봅시다 다같이 대박내봅시다 끝까지 최소 일주일 이면 다들 대박 나지 않을까요 최소 만원은 넘길테니까..
# cmt_url:  http://finance.naver.com/ncomment/list.nhn?ticketId=finance2&objectId=56459580&secureKey=j-2rP7uK5gK0al2LpLmbXzuXWp8IqYJegeGWe0tiLFWHCzmVksVqdQ&parentUrl=http%3A%2F%2Ffinance.naver.com%2Fitem%2Fboard_read.nhn%3Fcode%3D037230%26nid%3D56459580%26st%3D%26sw%3D%26page%3D1
#
# hits :  88
# title :  오늘부터 대박입니다 가자 다같이 대박..
# written_date :  2016.12.16 08:34
# is_sub :  True
# antipathy :  0
# sympathy :  1
# id :  qorr****
# inv_op :  의견없음
# ==========================================================================================
